# %%
import pandas as pd

# Leer el primer archivo CSV
df = pd.read_csv('./datos_tarjeta_sd.csv')

# Leer el segundo archivo CSV
df_bbdd = pd.read_csv('./datos_bbdd.csv')

# %%
df
# Out:
#       area   temp    hum     fecha      hora
# 1199     2  20.13  61.94  1/7/2024  09:06:25
# 915      1  19.97  50.15  1/7/2024  10:22:06
# 914      1  20.14  48.00  1/7/2024  10:12:07
# 913      1  20.31  52.51  1/7/2024  09:52:06
# 912      1  20.15  52.57  1/7/2024  09:42:07
# ...    ...    ...    ...       ...       ...
# 2110     1  20.53  49.45  9/7/2024  18:07:08
# 2109     1  20.49  48.64  9/7/2024  17:57:09
# 2108     1  20.55  49.25  9/7/2024  17:47:07
# 7340     2  20.08  53.84  9/7/2024  21:38:06
# 2089     1  20.37  49.66  9/7/2024  14:26:49
#
# [8928 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8928 entries, 0 to 8927
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    8928 non-null   int64
#  1   temp    8928 non-null   float64
#  2   hum     8928 non-null   float64
#  3   fecha   8928 non-null   object
#  4   hora    8928 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 348.9+ KB

# %%
df_bbdd
# Out:
#       area   temp    hum      fecha      hora
# 0        1  20.16  60.44   3/7/2024  08:54:46
# 1        2  20.13  61.94   3/7/2024  09:06:25
# 2        2  19.40  65.96   3/7/2024  09:13:33
# 3        1  20.89  60.60   3/7/2024  09:22:10
# 4        1  20.57  56.71   3/7/2024  09:32:08
# ...    ...    ...    ...        ...       ...
# 8923     2  20.17  51.32  31/7/2024  20:57:49
# 8924     2  20.09  52.01  31/7/2024  21:38:06
# 8925     2  20.08  53.92  31/7/2024  22:48:26
# 8926     2  20.14  54.03  31/7/2024  23:18:48
# 8927     2  20.06  54.03  31/7/2024  23:28:58
#
# [8928 rows x 5 columns]

# %%
df_bbdd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8928 entries, 0 to 8927
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    8928 non-null   int64
#  1   temp    8928 non-null   float64
#  2   hum     8928 non-null   float64
#  3   fecha   8928 non-null   object
#  4   hora    8928 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 348.9+ KB

# %%
validador = 0
# Verificar que ambas columnas tienen la misma cantidad de filas
if len(df) == len(df_bbdd):
    # Comparar los valores de las filas de ambas columnas
    for i in range(len(df)):
        if df['temp'][i] != df_bbdd['temp'][i]:
            print('*'*50)
            print(f'Valor diferente encontrado en la fila {i+1}')
            print(f'Dato en tarjeta SD: {df["temp"][i]}')
            print(f'Dato en BBDD: {df_bbdd["temp"][i]}')
            validador+=1
    if validador == 0:
      print('*'*50)
      print('Los valores de los registros son iguales')
      print('*'*50)
    else:
      print('*'*50)
      print(f'Hay {validador} incompatibilidades')
      print('*'*50)
else:
    print('Las columnas no tienen la misma cantidad de filas.')
# Out:
# **************************************************
# Los valores de los registros son iguales
# **************************************************
